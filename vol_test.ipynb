# %% [markdown]
# # Mode d'emploi sur l'utilisation de la librairie

# %% [markdown]
# #### Import des sous modules de la librairie

# %%
from kernel.tools import CalendarConvention
from kernel.market_data import InterpolationType, VolatilitySurfaceType, Market, RateCurveType

# %% [markdown]
# #### Informations renseignées par l'utilisateur (sur l'interface)

# %%
security = "SPX"
rate_curve_type = RateCurveType.RF_US_TREASURY
interpolation_type = InterpolationType.SVENSSON
volatility_surface_type = VolatilitySurfaceType.LOCAL
calendar = CalendarConvention.ACT_360

# %% [markdown]
# #### Initialisation du marché

# %%
market = Market(underlying_name=security,
                rate_curve_type=rate_curve_type,
                interpolation_type=interpolation_type,
                volatility_surface_type=volatility_surface_type,
                calendar_convention=calendar)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 market = Market(underlying_name=security,
#       2                 rate_curve_type=rate_curve_type,
#       3                 interpolation_type=interpolation_type,
#       4                 volatility_surface_type=volatility_surface_type,
#       5                 calendar_convention=calendar)
#
# File c:\Users\thibc\OneDrive\Documents\Dev\Structured-Product-Pricing-Python\kernel\market_data\market.py:49, in Market.__init__(self, underlying_name, rate_curve_type, interpolation_type, volatility_surface_type, calendar_convention, obs_frequency)
#      46 self._fetch_underlying_info()
#      48 self.volatility_surface = None
# ---> 49 self._fetch_volatility_surface()
#
# File c:\Users\thibc\OneDrive\Documents\Dev\Structured-Product-Pricing-Python\kernel\market_data\market.py:153, in Market._fetch_volatility_surface(self)
#     150 if self.rate_curve is None:
#     151     self._fetch_yield_curves()
# --> 153 volatility_surface = self.volatility_surface_type.value(option_data=option_data, rate_curve=self.rate_curve)
#     154 volatility_surface.calibrate_surface()
#     156 self.volatility_surface = volatility_surface
#
# TypeError: LocalVolatilitySurface.__init__() missing 1 required positional argument: 'svi_surface'

# %%
print(f"Volatility 1Y ATM: {market.get_volatility(market.underlying_asset.last_price, 1)}")
# Out:
# Volatility 1Y ATM: 0.17252278550818448

# %%
market.volatility_surface.display_smiles()

# %%
market.volatility_surface.display_surface()
